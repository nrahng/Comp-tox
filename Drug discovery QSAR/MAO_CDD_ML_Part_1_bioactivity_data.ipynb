# %% [markdown]
# # **Computational Drug Discovery [Part 1] Download Bioactivity Data**
#
#
# ---

# %% [markdown]
# ## **ChEMBL Database**
#
# The [*ChEMBL Database*](https://www.ebi.ac.uk/chembl/) is a database that contains curated bioactivity data of more than 2 million compounds. It is compiled from more than 76,000 documents, 1.2 million assays and the data spans 13,000 targets and 1,800 cells and 33,000 indications.
# [Data as of March 25, 2020; ChEMBL version 26].

# %% [markdown]
# ## **Installing libraries**

# %% [markdown]
# Install the ChEMBL web service package so that we can retrieve bioactivity data from the ChEMBL Database.

# %%
! pip install chembl_webresource_client
# Out:
# Requirement already satisfied: chembl_webresource_client in /usr/local/lib/python3.11/dist-packages (0.10.9)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.11/dist-packages (from chembl_webresource_client) (2.3.0)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.11/dist-packages (from chembl_webresource_client) (2.32.3)
# Requirement already satisfied: requests-cache~=1.2 in /usr/local/lib/python3.11/dist-packages (from chembl_webresource_client) (1.2.1)
# Requirement already satisfied: easydict in /usr/local/lib/python3.11/dist-packages (from chembl_webresource_client) (1.13)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.18.4->chembl_webresource_client) (2025.1.31)
# Requirement already satisfied: attrs>=21.2 in /usr/local/lib/python3.11/dist-packages (from requests-cache~=1.2->chembl_webresource_client) (25.1.0)
# Requirement already satisfied: cattrs>=22.2 in /usr/local/lib/python3.11/dist-packages (from requests-cache~=1.2->chembl_webresource_client) (24.1.2)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests-cache~=1.2->chembl_webresource_client) (4.3.6)
# Requirement already satisfied: url-normalize>=1.4 in /usr/local/lib/python3.11/dist-packages (from requests-cache~=1.2->chembl_webresource_client) (1.4.3)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from url-normalize>=1.4->requests-cache~=1.2->chembl_webresource_client) (1.17.0)

# %% [markdown]
# ## **Importing libraries**

# %%
# Import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# ## **Search for Target protein**

# %% [markdown]
# ### **Target search for Monoamine oxidase A**

# %%
# Target search for Monoamine oxidase A
target = new_client.target
target_query = target.search('Monoamine oxidase A')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#      cross_references           organism            pref_name  score  \
# 0                  []  Rattus norvegicus    Monoamine oxidase   32.0
# 1                  []       Homo sapiens    Monoamine oxidase   32.0
# 2                  []       Mus musculus    Monoamine oxidase   32.0
# 3                  []         Bos taurus    Monoamine oxidase   32.0
# 4                  []       Homo sapiens  Monoamine oxidase A   31.0
# ...               ...                ...                  ...    ...
# 7459               []       Homo sapiens       CDK15/Cyclin Y    0.0
# 7460               []       Homo sapiens       CDK5/Cyclin D3    0.0
# 7461               []       Homo sapiens     CDK11A/Cyclin L2    0.0
# 7462               []       Homo sapiens     CDK11B/Cyclin L2    0.0
# 7463               []       Homo sapiens        CDK1/Cyclin E    0.0
#
#       species_group_flag target_chembl_id  \
# 0                  False    CHEMBL2095196
# 1                  False    CHEMBL2095205
# 2                  False    CHEMBL2111442
# 3                  False    CHEMBL2111399
# 4                  False       CHEMBL1951
# ...                  ...              ...
# 7459               False    CHEMBL5483184
# 7460               False    CHEMBL5483185
# 7461               False    CHEMBL5483187
# 7462               False    CHEMBL5483188
# 7463               False    CHEMBL5483189
#
#                                       target_components  \
# 0     [{'accession': 'P19643', 'component_descriptio...
# 1     [{'accession': 'P21397', 'component_descriptio...
# 2     [{'accession': 'Q8BW75', 'component_descriptio...
# 3     [{'accession': 'P56560', 'component_descriptio...
# 4     [{'accession': 'P21397', 'component_descriptio...
# ...                                                 ...
# 7459  [{'accession': 'Q96Q40', 'component_descriptio...
# 7460  [{'accession': 'Q00535', 'component_descriptio...
# 7461  [{'accession': 'Q9UQ88', 'component_descriptio...
# 7462  [{'accession': 'P21127', 'component_descriptio...
# 7463  [{'accession': 'P06493', 'component_descriptio...
#
#                 target_type   tax_id
# 0            PROTEIN FAMILY  10116.0
# 1            PROTEIN FAMILY   9606.0
# 2            PROTEIN FAMILY  10090.0
# 3            PROTEIN FAMILY   9913.0
# 4            SINGLE PROTEIN   9606.0
# ...                     ...      ...
# 7459        PROTEIN COMPLEX   9606.0
# 7460        PROTEIN COMPLEX   9606.0
# 7461        PROTEIN COMPLEX   9606.0
# 7462        PROTEIN COMPLEX   9606.0
# 7463  PROTEIN COMPLEX GROUP   9606.0
#
# [7464 rows x 9 columns]

# %% [markdown]
# ### **Select and retrieve bioactivity data for *Monoamine oxidase* (4th entry)**

# %% [markdown]
# We will assign the fifth entry (which corresponds to the target protein monoamine oxidase A from homo sapiens) to the ***selected_target*** variable

# %%
selected_target = targets.target_chembl_id[4]
selected_target
# Out:
# 'CHEMBL1951'

# %% [markdown]
# Here, we will retrieve only bioactivity data for *monoamine oxidase A* (CHEMBL1951) that are reported as IC$_{50}$ values in nM (nanomolar) unit.

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df.head(3)
# Out:
#   action_type activity_comment  activity_id activity_properties  \
# 0        None             None       184068                  []
# 1        None             None       185442                  []
# 2        None             None       189322                  []
#
#   assay_chembl_id                                  assay_description  \
# 0    CHEMBL715193  Compound was tested for inhibition of monoamin...
# 1    CHEMBL715193  Compound was tested for inhibition of monoamin...
# 2    CHEMBL715193  Compound was tested for inhibition of monoamin...
#
#   assay_type assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0          B                    None                   None  BAO_0000190  ...
# 1          B                    None                   None  BAO_0000190  ...
# 2          B                    None                   None  BAO_0000190  ...
#
#   target_organism     target_pref_name target_tax_id text_value  toid  type  \
# 0    Homo sapiens  Monoamine oxidase A          9606       None  None  IC50
# 1    Homo sapiens  Monoamine oxidase A          9606       None  None  IC50
# 2    Homo sapiens  Monoamine oxidase A          9606       None  None  IC50
#
#   units    uo_units upper_value value
# 0    uM  UO_0000065        None  5.47
# 1    uM  UO_0000065        None  1.36
# 2    uM  UO_0000065        None  30.8
#
# [3 rows x 46 columns]

# %% [markdown]
# The lower IC50 value, the better the potency of the drug.

# %%
df.standard_type.unique()
# Out:
# array(['IC50'], dtype=object)

# %% [markdown]
# Finally we will save the resulting bioactivity data to a CSV file **bioactivity_data.csv**.

# %%
df.to_csv('bioactivity_data.csv', index=False)

# %% [markdown]
# ## **Copying files to Google Drive**

# %% [markdown]
# Firstly, we need to mount the Google Drive into Colab so that we can have access to our Google adrive from within Colab.

# %%
from google.colab import drive
drive.mount('/content/gdrive/', force_remount=True)
# Out:
# Mounted at /content/gdrive/

# %%
# !ls '/content/gdrive/My Drive/Colab Notebooks'
# Out:
# 'Copy of Final copy of RLO_Group4.ipynb'   MAO_CDD-ML-Part-1-bioactivity-data.ipynb
#  data					   rna_seq.ipynb

# %% [markdown]
# Next, we create a **data** folder in our **Colab Notebooks** folder on Google Drive.

# %%
! mkdir "/content/gdrive/My Drive/Colab Notebooks/data"
# Out:
# mkdir: cannot create directory ‘/content/gdrive/My Drive/Colab Notebooks/data’: File exists

# %%
! cp bioactivity_data.csv "/content/gdrive/My Drive/Colab Notebooks/data"

# %%
! ls -l "/content/gdrive/My Drive/Colab Notebooks/data"
# Out:
# total 3454
# -rw------- 1 root root 3270887 Feb  9 05:55 bioactivity_data.csv
# -rw------- 1 root root  265217 Feb  9 05:57 bioactivity_preprocessed_data.csv

# %% [markdown]
# Let's see the CSV files that we have so far.

# %%
! ls
# Out:
# bioactivity_data.csv  bioactivity_preprocessed_data.csv  gdrive  sample_data

# %% [markdown]
# Taking a glimpse of the **bioactivity_data.csv** file that we've just created.

# %%
! head bioactivity_data.csv
# Out:
# action_type,activity_comment,activity_id,activity_properties,assay_chembl_id,assay_description,assay_type,assay_variant_accession,assay_variant_mutation,bao_endpoint,bao_format,bao_label,canonical_smiles,data_validity_comment,data_validity_description,document_chembl_id,document_journal,document_year,ligand_efficiency,molecule_chembl_id,molecule_pref_name,parent_molecule_chembl_id,pchembl_value,potential_duplicate,qudt_units,record_id,relation,src_id,standard_flag,standard_relation,standard_text_value,standard_type,standard_units,standard_upper_value,standard_value,target_chembl_id,target_organism,target_pref_name,target_tax_id,text_value,toid,type,units,uo_units,upper_value,value
# ,,184068,[],CHEMBL715193,Compound was tested for inhibition of monoamine oxidase-A (MAO-A).,B,,,BAO_0000190,BAO_0000357,single protein format,C/N=C1/CCc2c1n(C)c1ccc(OC(=O)NCc3ccccc3)c(Br)c21,,,CHEMBL1151505,Bioorg Med Chem Lett,1996.0,"{'bei': '12.34', 'le': '0.27', 'lle': '0.67', 'sei': '9.46'}",CHEMBL156630,,CHEMBL156630,5.26,0,http://www.openphacts.org/units/Nanomolar,308504,=,1,1,=,,IC50,nM,,5470.0,CHEMBL1951,Homo sapiens,Monoamine oxidase A,9606,,,IC50,uM,UO_0000065,,5.47
# ,,185442,[],CHEMBL715193,Compound was tested for inhibition of monoamine oxidase-A (MAO-A).,B,,,BAO_0000190,BAO_0000357,single protein format,C/N=C1/CCc2c1n(C)c1ccc(OC(=O)NC)c(Cl)c21,,,CHEMBL1151505,Bioorg Med Chem Lett,1996.0,"{'bei': '19.19', 'le': '0.38', 'lle': '2.95', 'sei': '10.55'}",CHEMBL155754,,CHEMBL155754,5.87,0,http://www.openphacts.org/units/Nanomolar,308506,=,1,1,=,,IC50,nM,,1360.0,CHEMBL1951,Homo sapiens,Monoamine oxidase A,9606,,,IC50,uM,UO_0000065,,1.36
# ,,189322,[],CHEMBL715193,Compound was tested for inhibition of monoamine oxidase-A (MAO-A).,B,,,BAO_0000190,BAO_0000357,single protein format,CC(C)/N=C1/CCc2c1n(C)c1ccccc21,,,CHEMBL1151505,Bioorg Med Chem Lett,1996.0,"{'bei': '19.93', 'le': '0.36', 'lle': '1.19', 'sei': '26.09'}",CHEMBL348083,,CHEMBL348083,4.51,0,http://www.openphacts.org/units/Nanomolar,308492,=,1,1,=,,IC50,nM,,30800.0,CHEMBL1951,Homo sapiens,Monoamine oxidase A,9606,,,IC50,uM,UO_0000065,,30.8
# ,,190494,[],CHEMBL715193,Compound was tested for inhibition of monoamine oxidase-A (MAO-A).,B,,,BAO_0000190,BAO_0000357,single protein format,C/N=C1/CCc2c1n(C)c1cc(Cl)c(OC(=O)NC)cc21,,,CHEMBL1151505,Bioorg Med Chem Lett,1996.0,"{'bei': '15.20', 'le': '0.30', 'lle': '1.73', 'sei': '8.36'}",CHEMBL157182,,CHEMBL157182,4.65,0,http://www.openphacts.org/units/Nanomolar,308505,=,1,1,=,,IC50,nM,,22500.0,CHEMBL1951,Homo sapiens,Monoamine oxidase A,9606,,,IC50,uM,UO_0000065,,22.5
# ,,191747,[],CHEMBL715193,Compound was tested for inhibition of monoamine oxidase-A (MAO-A).,B,,,BAO_0000190,BAO_0000357,single protein format,COc1cc(Br)c2oc(C3CCNCC3)cc2c1,,,CHEMBL1151505,Bioorg Med Chem Lett,1996.0,"{'bei': '21.74', 'le': '0.51', 'lle': '3.07', 'sei': '19.61'}",CHEMBL160347,BROFAROMINE,CHEMBL160347,6.75,0,http://www.openphacts.org/units/Nanomolar,308496,=,1,1,=,,IC50,nM,,180.0,CHEMBL1951,Homo sapiens,Monoamine oxidase A,9606,,,IC50,uM,UO_0000065,,0.18
# ,,192851,[],CHEMBL715193,Compound was tested for inhibition of monoamine oxidase-A (MAO-A).,B,,,BAO_0000190,BAO_0000357,single protein format,CC/N=C1/CCc2c1n(C)c1ccccc21,,,CHEMBL1151505,Bioorg Med Chem Lett,1996.0,"{'bei': '26.72', 'le': '0.48', 'lle': '2.74', 'sei': '32.81'}",CHEMBL347197,,CHEMBL347197,5.67,0,http://www.openphacts.org/units/Nanomolar,308495,=,1,1,=,,IC50,nM,,2120.0,CHEMBL1951,Homo sapiens,Monoamine oxidase A,9606,,,IC50,uM,UO_0000065,,2.12
# ,,192853,[],CHEMBL715193,Compound was tested for inhibition of monoamine oxidase-A (MAO-A).,B,,,BAO_0000190,BAO_0000357,single protein format,CNC(=O)Oc1ccc2c(c1)c1c(n2C)/C(=N\CCc2ccccc2)CC1,Outside typical range,"Values for this activity type are unusually large/small, so may not be accurate",CHEMBL1151505,Bioorg Med Chem Lett,1996.0,,CHEMBL160219,,CHEMBL160219,,0,http://www.openphacts.org/units/Nanomolar,308508,>,1,1,>,,IC50,nM,,1000000.0,CHEMBL1951,Homo sapiens,Monoamine oxidase A,9606,,,IC50,uM,UO_0000065,,1000.0
# ,,192856,[],CHEMBL715193,Compound was tested for inhibition of monoamine oxidase-A (MAO-A).,B,,,BAO_0000190,BAO_0000357,single protein format,CCCn1c2c(c3c(Br)c(OC(=O)NC)ccc31)CC/C2=N/CC,Outside typical range,"Values for this activity type are unusually large/small, so may not be accurate",CHEMBL1151505,Bioorg Med Chem Lett,1996.0,,CHEMBL445916,,CHEMBL445916,,0,http://www.openphacts.org/units/Nanomolar,308499,>,1,1,>,,IC50,nM,,1000000.0,CHEMBL1951,Homo sapiens,Monoamine oxidase A,9606,,,IC50,uM,UO_0000065,,1000.0
# ,,194036,[],CHEMBL715193,Compound was tested for inhibition of monoamine oxidase-A (MAO-A).,B,,,BAO_0000190,BAO_0000357,single protein format,Cn1c2c(c3ccccc31)CC/C2=N/Cc1ccncc1,Outside typical range,"Values for this activity type are unusually large/small, so may not be accurate",CHEMBL1151505,Bioorg Med Chem Lett,1996.0,,CHEMBL158041,,CHEMBL158041,,0,http://www.openphacts.org/units/Nanomolar,308493,=,1,1,=,,IC50,nM,,113000.0,CHEMBL1951,Homo sapiens,Monoamine oxidase A,9606,,,IC50,uM,UO_0000065,,113.0

# %% [markdown]
# ## **Handling missing data**
# If any compounds has missing value for the **standard_value** and **canonical_smiles** column then drop it

# %%
df = pd.read_csv('bioactivity_data.csv')
df2 = df.dropna(subset=['standard_value'])

# Drop rows where 'canonical_smiles' is NaN
df2 = df2.dropna(subset=['canonical_smiles'])

len(df2)
# Out:
# 4222

# %%
len(df2.canonical_smiles.unique())
# Out:
# 3562

# %% [markdown]
# If the output of unique values is smaller than the number of rows, then we will know that we have duplicate values. In this case, the number of unqiue values is 3562. Therefore, we drop duplicate values.

# %%
df2 = df2.drop_duplicates(['canonical_smiles'])
df2 = df2.reset_index(drop=True)
df2
# Out:
#                                             action_type activity_comment  \
# 0                                                   NaN              NaN
# 1                                                   NaN              NaN
# 2                                                   NaN              NaN
# 3                                                   NaN              NaN
# 4                                                   NaN              NaN
# ...                                                 ...              ...
# 3557  {'action_type': 'INHIBITOR', 'description': 'N...              NaN
# 3558  {'action_type': 'INHIBITOR', 'description': 'N...              NaN
# 3559  {'action_type': 'INHIBITOR', 'description': 'N...              NaN
# 3560  {'action_type': 'INHIBITOR', 'description': 'N...              NaN
# 3561                                                NaN              NaN
#
#       activity_id                                activity_properties  \
# 0          184068                                                 []
# 1          185442                                                 []
# 2          189322                                                 []
# 3          190494                                                 []
# 4          191747                                                 []
# ...           ...                                                ...
# 3557     25658317  [{'comments': None, 'relation': '=', 'result_f...
# 3558     25658318  [{'comments': None, 'relation': '=', 'result_f...
# 3559     25731050                                                 []
# 3560     25731051                                                 []
# 3561     25787615  [{'comments': None, 'relation': None, 'result_...
#
#      assay_chembl_id                                  assay_description  \
# 0       CHEMBL715193  Compound was tested for inhibition of monoamin...
# 1       CHEMBL715193  Compound was tested for inhibition of monoamin...
# 2       CHEMBL715193  Compound was tested for inhibition of monoamin...
# 3       CHEMBL715193  Compound was tested for inhibition of monoamin...
# 4       CHEMBL715193  Compound was tested for inhibition of monoamin...
# ...              ...                                                ...
# 3557   CHEMBL5372889  Inhibition of human recombinant MAO-A expresse...
# 3558   CHEMBL5372889  Inhibition of human recombinant MAO-A expresse...
# 3559   CHEMBL5393270  Inhibition of recombinant MAO-A (unknown origi...
# 3560   CHEMBL5393270  Inhibition of recombinant MAO-A (unknown origi...
# 3561   CHEMBL5474438  Selectivity interaction (Monoamine Oxidase A, ...
#
#      assay_type  assay_variant_accession  assay_variant_mutation bao_endpoint  \
# 0             B                      NaN                     NaN  BAO_0000190
# 1             B                      NaN                     NaN  BAO_0000190
# 2             B                      NaN                     NaN  BAO_0000190
# 3             B                      NaN                     NaN  BAO_0000190
# 4             B                      NaN                     NaN  BAO_0000190
# ...         ...                      ...                     ...          ...
# 3557          B                      NaN                     NaN  BAO_0000190
# 3558          B                      NaN                     NaN  BAO_0000190
# 3559          T                      NaN                     NaN  BAO_0000190
# 3560          T                      NaN                     NaN  BAO_0000190
# 3561          B                      NaN                     NaN  BAO_0000190
#
#       ... target_organism     target_pref_name target_tax_id text_value toid  \
# 0     ...    Homo sapiens  Monoamine oxidase A          9606        NaN  NaN
# 1     ...    Homo sapiens  Monoamine oxidase A          9606        NaN  NaN
# 2     ...    Homo sapiens  Monoamine oxidase A          9606        NaN  NaN
# 3     ...    Homo sapiens  Monoamine oxidase A          9606        NaN  NaN
# 4     ...    Homo sapiens  Monoamine oxidase A          9606        NaN  NaN
# ...   ...             ...                  ...           ...        ...  ...
# 3557  ...    Homo sapiens  Monoamine oxidase A          9606        NaN  NaN
# 3558  ...    Homo sapiens  Monoamine oxidase A          9606        NaN  NaN
# 3559  ...    Homo sapiens  Monoamine oxidase A          9606        NaN  NaN
# 3560  ...    Homo sapiens  Monoamine oxidase A          9606        NaN  NaN
# 3561  ...    Homo sapiens  Monoamine oxidase A          9606        NaN  NaN
#
#       type units    uo_units upper_value   value
# 0     IC50    uM  UO_0000065         NaN   5.470
# 1     IC50    uM  UO_0000065         NaN   1.360
# 2     IC50    uM  UO_0000065         NaN  30.800
# 3     IC50    uM  UO_0000065         NaN  22.500
# 4     IC50    uM  UO_0000065         NaN   0.180
# ...    ...   ...         ...         ...     ...
# 3557  IC50    uM  UO_0000065         NaN   1.500
# 3558  IC50    uM  UO_0000065         NaN   1.180
# 3559  IC50    uM  UO_0000065         NaN  37.756
# 3560  IC50    uM  UO_0000065         NaN  25.431
# 3561  IC50    uM  UO_0000065         NaN  30.000
#
# [3562 rows x 46 columns]

# %% [markdown]
# ## **Data pre-processing of the bioactivity data**

# %% [markdown]
# ### **Labeling compounds as either being active, inactive or intermediate**
# The bioactivity data is in the IC50 unit. Compounds having values of less than 1000 nM will be considered to be **active** while those greater than 10,000 nM will be considered to be **inactive**. As for those values in between 1,000 and 10,000 nM will be referred to as **intermediate**.

# %%
bioactivity_class = []
for i in df2.standard_value:
  if float(i) >= 10000:
    bioactivity_class.append("inactive")
  elif float(i) <= 1000:
    bioactivity_class.append("active")
  else:
    bioactivity_class.append("intermediate")

df_value_bioactivity = pd.DataFrame({
    'standard_value': df2.standard_value,
    'bioactivity_class': bioactivity_class
})
print(df_value_bioactivity)
# Out:
#       standard_value bioactivity_class
# 0             5470.0      intermediate
# 1             1360.0      intermediate
# 2            30800.0          inactive
# 3            22500.0          inactive
# 4              180.0            active
# ...              ...               ...
# 3557          1500.0      intermediate
# 3558          1180.0      intermediate
# 3559         37756.0          inactive
# 3560         25431.0          inactive
# 3561         30000.0          inactive
#
# [3562 rows x 2 columns]

# %% [markdown]
# ### **Combine molecule_chembl_id, canonical_smiles, standard_valu, and bioactivity_class into a DataFrame into a new df**

# %%
selection = ['molecule_chembl_id', 'canonical_smiles', 'standard_value']
df3 = df2[selection]
df3
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL156630   C/N=C1/CCc2c1n(C)c1ccc(OC(=O)NCc3ccccc3)c(Br)c21
# 1          CHEMBL155754           C/N=C1/CCc2c1n(C)c1ccc(OC(=O)NC)c(Cl)c21
# 2          CHEMBL348083                     CC(C)/N=C1/CCc2c1n(C)c1ccccc21
# 3          CHEMBL157182           C/N=C1/CCc2c1n(C)c1cc(Cl)c(OC(=O)NC)cc21
# 4          CHEMBL160347                      COc1cc(Br)c2oc(C3CCNCC3)cc2c1
# ...                 ...                                                ...
# 3557      CHEMBL5398630  O=C(O)/C=C/C(=O)O.[2H]C([2H])(Cc1c[nH]c2ccccc1...
# 3558      CHEMBL3183055          CN(C)CCc1c[nH]c2ccccc12.O=C(O)/C=C/C(=O)O
# 3559           CHEMBL91        Clc1ccc(COC(Cn2ccnc2)c2ccc(Cl)cc2Cl)c(Cl)c1
# 3560          CHEMBL104             Clc1ccccc1C(c1ccccc1)(c1ccccc1)n1ccnc1
# 3561      CHEMBL3643413  CCC(=O)N1CC[C@H](Nc2ncnc3c2CN(c2cnc(OC)c(C(F)(...
#
#       standard_value
# 0             5470.0
# 1             1360.0
# 2            30800.0
# 3            22500.0
# 4              180.0
# ...              ...
# 3557          1500.0
# 3558          1180.0
# 3559         37756.0
# 3560         25431.0
# 3561         30000.0
#
# [3562 rows x 3 columns]

# %%
print(len(bioactivity_class))
print(len(df3))
df3.loc[:, 'bioactivity_class'] = bioactivity_class
df3 = df3.reset_index(drop=True)
df3
# Out:
# 3562
# 3562
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL156630   C/N=C1/CCc2c1n(C)c1ccc(OC(=O)NCc3ccccc3)c(Br)c21
# 1          CHEMBL155754           C/N=C1/CCc2c1n(C)c1ccc(OC(=O)NC)c(Cl)c21
# 2          CHEMBL348083                     CC(C)/N=C1/CCc2c1n(C)c1ccccc21
# 3          CHEMBL157182           C/N=C1/CCc2c1n(C)c1cc(Cl)c(OC(=O)NC)cc21
# 4          CHEMBL160347                      COc1cc(Br)c2oc(C3CCNCC3)cc2c1
# ...                 ...                                                ...
# 3557      CHEMBL5398630  O=C(O)/C=C/C(=O)O.[2H]C([2H])(Cc1c[nH]c2ccccc1...
# 3558      CHEMBL3183055          CN(C)CCc1c[nH]c2ccccc12.O=C(O)/C=C/C(=O)O
# 3559           CHEMBL91        Clc1ccc(COC(Cn2ccnc2)c2ccc(Cl)cc2Cl)c(Cl)c1
# 3560          CHEMBL104             Clc1ccccc1C(c1ccccc1)(c1ccccc1)n1ccnc1
# 3561      CHEMBL3643413  CCC(=O)N1CC[C@H](Nc2ncnc3c2CN(c2cnc(OC)c(C(F)(...
#
#       standard_value bioactivity_class
# 0             5470.0      intermediate
# 1             1360.0      intermediate
# 2            30800.0          inactive
# 3            22500.0          inactive
# 4              180.0            active
# ...              ...               ...
# 3557          1500.0      intermediate
# 3558          1180.0      intermediate
# 3559         37756.0          inactive
# 3560         25431.0          inactive
# 3561         30000.0          inactive
#
# [3562 rows x 4 columns]

# %% [markdown]
# Saves dataframe to CSV file

# %%
df3.to_csv('bioactivity_preprocessed_data.csv', index=False)

# %%
! ls -l
# Out:
# total 3464
# -rw-r--r-- 1 root root 3271526 Feb  9 06:12 bioactivity_data.csv
# -rw-r--r-- 1 root root  265217 Feb  9 06:27 bioactivity_preprocessed_data.csv
# drwx------ 7 root root    4096 Feb  9 06:12 gdrive
# drwxr-xr-x 1 root root    4096 Feb  6 14:19 sample_data

# %% [markdown]
# Let's copy to the Google Drive

# %%
! cp bioactivity_preprocessed_data.csv "/content/gdrive/My Drive/Colab Notebooks/data"

# %%
! ls "/content/gdrive/My Drive/Colab Notebooks/data"
# Out:
# bioactivity_data.csv  bioactivity_preprocessed_data.csv

# %% [markdown]
# ---
